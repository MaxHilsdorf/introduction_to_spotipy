# %% [markdown]
# # An Introduction to Spotipy

# %% [markdown]
# This notebook serves as supplementary material for my medium article called "How to Create Large Music Datasets in 3 Steps Using Spotipy".

# %% [markdown]
# ## 1. Imports and Authorization

# %% [markdown]
# Imports

# %%
import spotipy
import spotipy.util as util
import pandas as pd # for later

# %% [markdown]
# Authorization

# %%
CLIENT_ID = "ClientID" # enter your own here
CLIENT_SECRET = "SecretClientID" # enter your own here

# %%
token = util.oauth2.SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
cache_token = token.get_access_token()
sp = spotipy.Spotify(cache_token)

# %% [markdown]
# ## 2. Find Playlist to Analyze

# %%
playlist_creator = "spotify"
playlist_id = "37i9dQZF1DX5IDTimEWoTd"

# %% [markdown]
# ## 3. Analyze Playlist Tracks

# %% [markdown]
# ### 3.1 Analyze a Single Playlist

# %% [markdown]
# Use the sp.user_playlist_tracks function.

# %%
sp.user_playlist_tracks(playlist_creator, playlist_id)
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX5IDTimEWoTd/tracks?offset=0&limit=100',
#  'items': [{'added_at': '2020-04-22T15:52:26Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4IWBUUAFIplrNtaOHcJPRM'},
#        'href': 'https://api.spotify.com/v1/artists/4IWBUUAFIplrNtaOHcJPRM',
#        'id': '4IWBUUAFIplrNtaOHcJPRM',
#        'name': 'James Arthur',
#        'type': 'artist',
#        'uri': 'spotify:artist:4IWBUUAFIplrNtaOHcJPRM'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6Vd7ZTFfhrtPuiQIqEN8XU'},
#      'href': 'https://api.spotify.com/v1/albums/6Vd7ZTFfhrtPuiQIqEN8XU',
#      'id': '6Vd7ZTFfhrtPuiQIqEN8XU',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273287581424579344780ccdc66',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02287581424579344780ccdc66',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851287581424579344780ccdc66',
#        'width': 64}],
#      'name': 'Falling Like The Stars',
#      'release_date': '2019-05-10',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:6Vd7ZTFfhrtPuiQIqEN8XU'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4IWBUUAFIplrNtaOHcJPRM'},
#       'href': 'https://api.spotify.com/v1/artists/4IWBUUAFIplrNtaOHcJPRM',
#       'id': '4IWBUUAFIplrNtaOHcJPRM',
#       'name': 'James Arthur',
#       'type': 'artist',
#       'uri': 'spotify:artist:4IWBUUAFIplrNtaOHcJPRM'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 212720,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEE861901791'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/15xWRPHQMeqgdkGzInx3PY'},
#     'href': 'https://api.spotify.com/v1/tracks/15xWRPHQMeqgdkGzInx3PY',
#     'id': '15xWRPHQMeqgdkGzInx3PY',
#     'is_local': False,
#     'name': 'Falling Like The Stars',
#     'popularity': 79,
#     'preview_url': 'https://p.scdn.co/mp3-preview/07122d8ecd5fbec4e57fab791d86df8e9e5aaa82?cid=d67635d3c8a04dc084f1237db0d3c1d3',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:15xWRPHQMeqgdkGzInx3PY'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-04-22T15:52:26Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5JZ7CnR6gTvEMKX4g70Amv'},
#        'href': 'https://api.spotify.com/v1/artists/5JZ7CnR6gTvEMKX4g70Amv',
#        'id': '5JZ7CnR6gTvEMKX4g70Amv',
#        'name': 'Lauv',
#        'type': 'artist',
#        'uri': 'spotify:artist:5JZ7CnR6gTvEMKX4g70Amv'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2Ivz1Ch7qB9yR3uLr8T1pj'},
#      'href': 'https://api.spotify.com/v1/albums/2Ivz1Ch7qB9yR3uLr8T1pj',
#      'id': '2Ivz1Ch7qB9yR3uLr8T1pj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27367d85e3eeac43ca5fed441a4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0267d85e3eeac43ca5fed441a4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485167d85e3eeac43ca5fed441a4',
#        'width': 64}],
#      'name': 'Spotify Singles',
#      'release_date': '2017-07-19',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:2Ivz1Ch7qB9yR3uLr8T1pj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5JZ7CnR6gTvEMKX4g70Amv'},
#       'href': 'https://api.spotify.com/v1/artists/5JZ7CnR6gTvEMKX4g70Amv',
#       'id': '5JZ7CnR6gTvEMKX4g70Amv',
#       'name': 'Lauv',
#       'type': 'artist',
#       'uri': 'spotify:artist:5JZ7CnR6gTvEMKX4g70Amv'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 202684,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBWWP1703024'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2uQNcZYa0SEbfW4cj0d9OS'},
#     'href': 'https://api.spotify.com/v1/tracks/2uQNcZYa0SEbfW4cj0d9OS',
#     'id': '2uQNcZYa0SEbfW4cj0d9OS',
#     'is_local': False,
#     'name': 'I Like Me Better - Recorded at Spotify Studios NYC',
#     'popularity': 69,
#     'preview_url': 'https://p.scdn.co/mp3-preview/cf9da5c0ea8450d89f1f1680e7d08caa14e6639d?cid=d67635d3c8a04dc084f1237db0d3c1d3',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2uQNcZYa0SEbfW4cj0d9OS'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-04-22T15:52:26Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/7n2wHs1TKAczGzO7Dd2rGr'},
#        'href': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr',
#        'id': '7n2wHs1TKAczGzO7Dd2rGr',
#        'name': 'Shawn Mendes',
#        'type': 'artist',
#        'uri': 'spotify:artist:7n2wHs1TKAczGzO7Dd2rGr'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2UfvnX1YYeC2cExMQTMbXC'},
#      'href': 'https://api.spotify.com/v1/albums/2UfvnX1YYeC2cExMQTMbXC',
#      'id': '2UfvnX1YYeC2cExMQTMbXC',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27359457bdb1edb5c6417f3baa2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0259457bdb1edb5c6417f3baa2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485159457bdb1edb5c6417f3baa2',
#        'width': 64}],
#      'name': 'Lover (Remix) [feat. Shawn Mendes]',
#      'release_date': '2019-11-13',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2UfvnX1YYeC2cExMQTMbXC'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7n2wHs1TKAczGzO7Dd2rGr'},
#       'href': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr',
#       'id': '7n2wHs1TKAczGzO7Dd2rGr',
#       'name': 'Shawn Mendes',
#       'type': 'artist',
#       'uri': 'spotify:artist:7n2wHs1TKAczGzO7Dd2rGr'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 221306,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUG11901492'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3i9UVldZOE0aD0JnyfAZZ0'},
#     'href': 'https://api.spotify.com/v1/tracks/3i9UVldZOE0aD0JnyfAZZ0',
#     'id': '3i9UVldZOE0aD0JnyfAZZ0',
#     'is_local': False,
#     'name': 'Lover (Remix) [feat. Shawn Mendes]',
#     'popularity': 80,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3i9UVldZOE0aD0JnyfAZZ0'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-04-22T15:52:26Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#        'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#        'id': '6eUKZXaKkcviH0Ku9w2n3V',
#        'name': 'Ed Sheeran',
#        'type': 'artist',
#        'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1ooV8YZC1KbpEcrmI8WH0F'},
#        'href': 'https://api.spotify.com/v1/artists/1ooV8YZC1KbpEcrmI8WH0F',
#        'id': '1ooV8YZC1KbpEcrmI8WH0F',
#        'name': 'Yebba',
#        'type': 'artist',
#        'uri': 'spotify:artist:1ooV8YZC1KbpEcrmI8WH0F'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6Z5DhADmyybfKNdymaPLjB'},
#      'href': 'https://api.spotify.com/v1/albums/6Z5DhADmyybfKNdymaPLjB',
#      'id': '6Z5DhADmyybfKNdymaPLjB',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b10514798bce97e3dff3607e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b10514798bce97e3dff3607e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b10514798bce97e3dff3607e',
#        'width': 64}],
#      'name': 'Best Part of Me (feat. YEBBA)',
#      'release_date': '2019-07-05',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:6Z5DhADmyybfKNdymaPLjB'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1ooV8YZC1KbpEcrmI8WH0F'},
#       'href': 'https://api.spotify.com/v1/artists/1ooV8YZC1KbpEcrmI8WH0F',
#       'id': '1ooV8YZC1KbpEcrmI8WH0F',
#       'name': 'Yebba',
#       'type': 'artist',
#       'uri': 'spotify:artist:1ooV8YZC1KbpEcrmI8WH0F'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 243266,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHS1900941'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5ug4vqGZ3eisGhY1IsziNX'},
#     'href': 'https://api.spotify.com/v1/tracks/5ug4vqGZ3eisGhY1IsziNX',
#     'id': '5ug4vqGZ3eisGhY1IsziNX',
#     'is_local': False,
#     'name': 'Best Part of Me (feat. YEBBA)',
#     'popularity': 74,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9b06d400381716c72ee93e5d1db73b2e21158e96?cid=d67635d3c8a04dc084f1237db0d3c1d3',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5ug4vqGZ3eisGhY1IsziNX'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-04-22T15:52:26Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Hsdzj7Dlq2I7tHP7501T4'},
#        'href': 'https://api.spotify.com/v1/artists/1Hsdzj7Dlq2I7tHP7501T4',
#        'id': '1Hsdzj7Dlq2I7tHP7501T4',
#        'name': 'Niall Horan',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Hsdzj7Dlq2I7tHP7501T4'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7dUgmUMDNnQAejhNLeIQWz'},
#      'href': 'https://api.spotify.com/v1/albums/7dUgmUMDNnQAejhNLeIQWz',
#      'id': '7dUgmUMDNnQAejhNLeIQWz',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731bd04431e42ed2105ea3534a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021bd04431e42ed2105ea3534a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511bd04431e42ed2105ea3534a',
#        'width': 64}],
#      'name': 'Put A Little Love On Me',
#      'release_date': '2019-12-06',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7dUgmUMDNnQAejhNLeIQWz'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Hsdzj7Dlq2I7tHP7501T4'},
#       'href': 'https://api.spotify.com/v1/artists/1Hsdzj7Dlq2I7tHP7501T4',
#       'id': '1Hsdzj7Dlq2I7tHP7501T4',
#       'name': 'Niall Horan',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Hsdzj7Dlq2I7tHP7501T4'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 224585,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUG11904166'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1hCTxutVVYvggAQcUUUZAT'},
#     'href': 'https://api.spotify.com/v1/tracks/1hCTxutVVYvggAQcUUUZAT',
#     'id': '1hCTxutVVYvggAQcUUUZAT',
#     'is_local': False,
#     'name': 'Put A Little Love On Me',
#     'popularity': 77,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1hCTxutVVYvggAQcUUUZAT'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-04-22T15:52:26Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7z5WFjZAIYejWy0NI5lv4T'},
#        'href': 'https://api.spotify.com/v1/artists/7z5WFjZAIYejWy0NI5lv4T',
#        'id': '7z5WFjZAIYejWy0NI5lv4T',
#        'name': 'Dan + Shay',
#        'type': 'artist',
#        'uri': 'spotify:artist:7z5WFjZAIYejWy0NI5lv4T'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#        'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#        'id': '1uNFoZAHBGtllmzznpCI3s',
#        'name': 'Justin Bieber',
#        'type': 'artist',
#        'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2YtdV4AkQesuqE6UwSADk7'},
#      'href': 'https://api.spotify.com/v1/albums/2YtdV4AkQesuqE6UwSADk7',
#      'id': '2YtdV4AkQesuqE6UwSADk7',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730b8355d0f5ecf6a050e9890c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020b8355d0f5ecf6a050e9890c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510b8355d0f5ecf6a050e9890c',
#        'width': 64}],
#      'name': '10,000 Hours (with Justin Bieber) [Piano]',
#      'release_date': '2019-11-27',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2YtdV4AkQesuqE6UwSADk7'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7z5WFjZAIYejWy0NI5lv4T'},
#       'href': 'https://api.spotify.com/v1/artists/7z5WFjZAIYejWy0NI5lv4T',
#       'id': '7z5WFjZAIYejWy0NI5lv4T',
#       'name': 'Dan + Shay',
#       'type': 'artist',
#       'uri': 'spotify:artist:7z5WFjZAIYejWy0NI5lv4T'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#       'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#       'id': '1uNFoZAHBGtllmzznpCI3s',
#       'name': 'Justin Bieber',
#       'type': 'artist',
#       'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 172320,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB11903147'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6HjF1gzVEZMb4GplnGl9B3'},
#     'href': 'https://api.spotify.com/v1/tracks/6HjF1gzVEZMb4GplnGl9B3',
#     'id': '6HjF1gzVEZMb4GplnGl9B3',
#     'is_local': False,
#     'name': '10,000 Hours (with Justin Bieber) - Piano',
#     'popularity': 71,
#     'preview_url': 'https://p.scdn.co/mp3-preview/45cc9760bbef1233b302f9e53729f240d3acb087?cid=d67635d3c8a04dc084f1237db0d3c1d3',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6HjF1gzVEZMb4GplnGl9B3'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-04-22T15:52:26Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qGkLCMQkNGOJ079iEcC5k'},
#        'href': 'https://api.spotify.com/v1/artists/6qGkLCMQkNGOJ079iEcC5k',
#        'id': '6qGkLCMQkNGOJ079iEcC5k',
#        'name': 'Ben Platt',
#        'type': 'artist',
#        'uri': 'spotify:artist:6qGkLCMQkNGOJ079iEcC5k'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2AluSp6sapRu17yc4r2a5F'},
#      'href': 'https://api.spotify.com/v1/albums/2AluSp6sapRu17yc4r2a5F',
#      'id': '2AluSp6sapRu17yc4r2a5F',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f77cc81c4679525b9f6b4447',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f77cc81c4679525b9f6b4447',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f77cc81c4679525b9f6b4447',
#        'width': 64}],
#      'name': 'Sing To Me Instead',
#      'release_date': '2019-03-29',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:2AluSp6sapRu17yc4r2a5F'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qGkLCMQkNGOJ079iEcC5k'},
#       'href': 'https://api.spotify.com/v1/artists/6qGkLCMQkNGOJ079iEcC5k',
#       'id': '6qGkLCMQkNGOJ079iEcC5k',
#       'name': 'Ben Platt',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qGkLCMQkNGOJ079iEcC5k'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 249426,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USAT21900696'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6hYvw3LLTViP2mT4MpDNmT'},
#     'href': 'https://api.spotify.com/v1/tracks/6hYvw3LLTViP2mT4MpDNmT',
#     'id': '6hYvw3LLTViP2mT4MpDNmT',
#     'is_local': False,
#     'name': 'Grow As We Go',
#     'popularity': 71,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ef89ad6d8da7b7a6be355d88e7728a9ccfdc15d3?cid=d67635d3c8a04dc084f1237db0d3c1d3',
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:6hYvw3LLTViP2mT4MpDNmT'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-04-22T15:52:26Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66W9LaWS0DPdL7Sz8iYGYe'},
#        'href': 'https://api.spotify.com/v1/artists/66W9LaWS0DPdL7Sz8iYGYe',
#        'id': '66W9LaWS0DPdL7Sz8iYGYe',
#        'name': 'JP Saxe',
#        'type': 'artist',
#        'uri': 'spotify:artist:66W9LaWS0DPdL7Sz8iYGYe'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0ZED1XzwlLHW4ZaG4lOT6m'},
#        'href': 'https://api.spotify.com/v1/artists/0ZED1XzwlLHW4ZaG4lOT6m',
#        'id': '0ZED1XzwlLHW4ZaG4lOT6m',
#        'name': 'Julia Michaels',
#        'type': 'artist',
#        'uri': 'spotify:artist:0ZED1XzwlLHW4ZaG4lOT6m'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7BrlhEO8dHiNmU8A1Ep9RZ'},
#      'href': 'https://api.spotify.com/v1/albums/7BrlhEO8dHiNmU8A1Ep9RZ',
#      'id': '7BrlhEO8dHiNmU8A1Ep9RZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273dedbec8cca43642f06533476',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02dedbec8cca43642f06533476',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851dedbec8cca43642f06533476',
#        'width': 64}],
#      'name': 'If the World Was Ending (feat. Julia Michaels)',
#      'release_date': '2019-10-17',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7BrlhEO8dHiNmU8A1Ep9RZ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66W9LaWS0DPdL7Sz8iYGYe'},
#       'href': 'https://api.spotify.com/v1/artists/66W9LaWS0DPdL7Sz8iYGYe',
#       'id': '66W9LaWS0DPdL7Sz8iYGYe',
#       'name': 'JP Saxe',
#       'type': 'artist',
#       'uri': 'spotify:artist:66W9LaWS0DPdL7Sz8iYGYe'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0ZED1XzwlLHW4ZaG4lOT6m'},
#       'href': 'https://api.spotify.com/v1/artists/0ZED1XzwlLHW4ZaG4lOT6m',
#       'id': '0ZED1XzwlLHW4ZaG4lOT6m',
#       'name': 'Julia Michaels',
#       'type': 'artist',
#       'uri': 'spotify:artist:0ZED1XzwlLHW4ZaG4lOT6m'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 208687,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USQX91902708'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2kJwzbxV2ppxnQoYw4GLBZ'},
#     'href': 'https://api.spotify.com/v1/tracks/2kJwzbxV2ppxnQoYw4GLBZ',
#     'id': '2kJwzbxV2ppxnQoYw4GLBZ',
#     'is_local': False,
#     'name': 'If the World Was Ending - feat. Julia Michaels',
#     'popularity': 90,
#     'preview_url': 'https://p.scdn.co/mp3-preview/018d975f965ed16e92e601c53afa1c7e7ce9ab27?cid=d67635d3c8a04dc084f1237db0d3c1d3',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2kJwzbxV2ppxnQoYw4GLBZ'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-04-22T15:52:26Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0DxPHf2flBAcV2SnZPg3SV'},
#        'href': 'https://api.spotify.com/v1/artists/0DxPHf2flBAcV2SnZPg3SV',
#        'id': '0DxPHf2flBAcV2SnZPg3SV',
#        'name': 'Jake Scott',
#        'type': 'artist',
#        'uri': 'spotify:artist:0DxPHf2flBAcV2SnZPg3SV'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2RROzxwoUk6XwB272Fnh6B'},
#      'href': 'https://api.spotify.com/v1/albums/2RROzxwoUk6XwB272Fnh6B',
#      'id': '2RROzxwoUk6XwB272Fnh6B',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27313c6cc24705dbbca23f75d86',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0213c6cc24705dbbca23f75d86',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485113c6cc24705dbbca23f75d86',
#        'width': 64}],
#      'name': 'Favorite T-Shirt (Acoustic)',
#      'release_date': '2019-11-08',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2RROzxwoUk6XwB272Fnh6B'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0DxPHf2flBAcV2SnZPg3SV'},
#       'href': 'https://api.spotify.com/v1/artists/0DxPHf2flBAcV2SnZPg3SV',
#       'id': '0DxPHf2flBAcV2SnZPg3SV',
#       'name': 'Jake Scott',
#       'type': 'artist',
#       'uri': 'spotify:artist:0DxPHf2flBAcV2SnZPg3SV'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 188442,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'QM24S1926716'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0sem2PTbwYJdCHoDn487TE'},
#     'href': 'https://api.spotify.com/v1/tracks/0sem2PTbwYJdCHoDn487TE',
#     'id': '0sem2PTbwYJdCHoDn487TE',
#     'is_local': False,
#     'name': 'Favorite T-Shirt (Acoustic)',
#     'popularity': 46,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0sem2PTbwYJdCHoDn487TE'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-04-22T15:52:26Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Hc9oDGvStNGmnj44m8sHg'},
#        'href': 'https://api.spotify.com/v1/artists/5Hc9oDGvStNGmnj44m8sHg',
#        'id': '5Hc9oDGvStNGmnj44m8sHg',
#        'name': 'Tyler Ward',
#        'type': 'artist',
#        'uri': 'spotify:artist:5Hc9oDGvStNGmnj44m8sHg'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1U9tVmBqCyiaP2gDSVwDIX'},
#        'href': 'https://api.spotify.com/v1/artists/1U9tVmBqCyiaP2gDSVwDIX',
#        'id': '1U9tVmBqCyiaP2gDSVwDIX',
#        'name': 'Karis',
#        'type': 'artist',
#        'uri': 'spotify:artist:1U9tVmBqCyiaP2gDSVwDIX'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4lf5sycK82JMzmkebi1Kic'},
#        'href': 'https://api.spotify.com/v1/artists/4lf5sycK82JMzmkebi1Kic',
#        'id': '4lf5sycK82JMzmkebi1Kic',
#        'name': 'Ray Lorraine',
#        'type': 'artist',
#        'uri': 'spotify:artist:4lf5sycK82JMzmkebi1Kic'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1reyQmIGDNOUhJiVd78sZZ'},
#      'href': 'https://api.spotify.com/v1/albums/1reyQmIGDNOUhJiVd78sZZ',
#      'id': '1reyQmIGDNOUhJiVd78sZZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ead203a9911e2f25e2b2d370',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ead203a9911e2f25e2b2d370',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ead203a9911e2f25e2b2d370',
#        'width': 64}],
#      'name': 'One More Time Around',
#      'release_date': '2019-09-20',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:1reyQmIGDNOUhJiVd78sZZ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Hc9oDGvStNGmnj44m8sHg'},
#       'href': 'https://api.spotify.com/v1/artists/5Hc9oDGvStNGmnj44m8sHg',
#       'id': '5Hc9oDGvStNGmnj44m8sHg',
#       'name': 'Tyler Ward',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Hc9oDGvStNGmnj44m8sHg'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1U9tVmBqCyiaP2gDSVwDIX'},
#       'href': 'https://api.spotify.com/v1/artists/1U9tVmBqCyiaP2gDSVwDIX',
#       'id': '1U9tVmBqCyiaP2gDSVwDIX',
#       'name': 'Karis',
#       'type': 'artist',
#       'uri': 'spotify:artist:1U9tVmBqCyiaP2gDSVwDIX'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4lf5sycK82JMzmkebi1Kic'},
#       'href': 'https://api.spotify.com/v1/artists/4lf5sycK82JMzmkebi1Kic',
#       'id': '4lf5sycK82JMzmkebi1Kic',
#       'name': 'Ray Lorraine',
#       'type': 'artist',
#       'uri': 'spotify:artist:4lf5sycK82JMzmkebi1Kic'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 205666,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBDMT1900207'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3DyhwZyBFedvnt68fMi6vf'},
#     'href': 'https://api.spotify.com/v1/tracks/3DyhwZyBFedvnt68fMi6vf',
#     'id': '3DyhwZyBFedvnt68fMi6vf',
#     'is_local': False,
#     'name': 'One More Time Around',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7bb5c911f45d4526cd609461743597c9c7cdce92?cid=d67635d3c8a04dc084f1237db0d3c1d3',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3DyhwZyBFedvnt68fMi6vf'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-04-22T15:52:26Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gOdHgIoIKoe4i9Tta6qdD'},
#        'href': 'https://api.spotify.com/v1/artists/7gOdHgIoIKoe4i9Tta6qdD',
#        'id': '7gOdHgIoIKoe4i9Tta6qdD',
#        'name': 'Jonas Brothers',
#        'type': 'artist',
#        'uri': 'spotify:artist:7gOdHgIoIKoe4i9Tta6qdD'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1Uf67JAtkVWfdydzFFqNF2'},
#      'href': 'https://api.spotify.com/v1/albums/1Uf67JAtkVWfdydzFFqNF2',
#      'id': '1Uf67JAtkVWfdydzFFqNF2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273de1a3a5eaa0c75bb18e7b597',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02de1a3a5eaa0c75bb18e7b597',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851de1a3a5eaa0c75bb18e7b597',
#        'width': 64}],
#      'name': 'Happiness Begins',
#      'release_date': '2019-06-07',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:1Uf67JAtkVWfdydzFFqNF2'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gOdHgIoIKoe4i9Tta6qdD'},
# ...
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/13saZpZnCDWOI9D4IJhp1f'},
#        'href': 'https://api.spotify.com/v1/artists/13saZpZnCDWOI9D4IJhp1f',
#        'id': '13saZpZnCDWOI9D4IJhp1f',
#        'name': 'Lily Allen',
#        'type': 'artist',
#        'uri': 'spotify:artist:13saZpZnCDWOI9D4IJhp1f'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2BWTPrj9yBBC79fCByZ2Tv'},
#      'href': 'https://api.spotify.com/v1/albums/2BWTPrj9yBBC79fCByZ2Tv',
#      'id': '2BWTPrj9yBBC79fCByZ2Tv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273898001fed87ec92038aec2ff',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02898001fed87ec92038aec2ff',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851898001fed87ec92038aec2ff',
#        'width': 64}],
#      'name': 'Somewhere Only We Know',
#      'release_date': '2013-11-10',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2BWTPrj9yBBC79fCByZ2Tv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/13saZpZnCDWOI9D4IJhp1f'},
#       'href': 'https://api.spotify.com/v1/artists/13saZpZnCDWOI9D4IJhp1f',
#       'id': '13saZpZnCDWOI9D4IJhp1f',
#       'name': 'Lily Allen',
#       'type': 'artist',
#       'uri': 'spotify:artist:13saZpZnCDWOI9D4IJhp1f'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 208154,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAYE1301770'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3DDGhkxq3FeUorZppSgeLE'},
#     'href': 'https://api.spotify.com/v1/tracks/3DDGhkxq3FeUorZppSgeLE',
#     'id': '3DDGhkxq3FeUorZppSgeLE',
#     'is_local': False,
#     'name': 'Somewhere Only We Know',
#     'popularity': 64,
#     'preview_url': 'https://p.scdn.co/mp3-preview/bf3c873201949f2f5d378d22d2f4c03753ea72e9?cid=d67635d3c8a04dc084f1237db0d3c1d3',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3DDGhkxq3FeUorZppSgeLE'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-04-22T15:52:26Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#        'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#        'id': '4gzpq5DPGxSnKTe4SA8HAU',
#        'name': 'Coldplay',
#        'type': 'artist',
#        'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0RHX9XECH8IVI3LNgWDpmQ'},
#      'href': 'https://api.spotify.com/v1/albums/0RHX9XECH8IVI3LNgWDpmQ',
#      'id': '0RHX9XECH8IVI3LNgWDpmQ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ad6f442ecac8735b9285a923',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ad6f442ecac8735b9285a923',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ad6f442ecac8735b9285a923',
#        'width': 64}],
#      'name': 'A Rush of Blood to the Head',
#      'release_date': '2002-08-08',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:0RHX9XECH8IVI3LNgWDpmQ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#       'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#       'id': '4gzpq5DPGxSnKTe4SA8HAU',
#       'name': 'Coldplay',
#       'type': 'artist',
#       'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 309600,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAYE0200772'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/75JFxkI2RXiU7L9VXzMkle'},
#     'href': 'https://api.spotify.com/v1/tracks/75JFxkI2RXiU7L9VXzMkle',
#     'id': '75JFxkI2RXiU7L9VXzMkle',
#     'is_local': False,
#     'name': 'The Scientist',
#     'popularity': 84,
#     'preview_url': 'https://p.scdn.co/mp3-preview/95cb9df1b056d759920b5e85ad7f9aff0a390671?cid=d67635d3c8a04dc084f1237db0d3c1d3',
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:75JFxkI2RXiU7L9VXzMkle'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-04-22T15:52:26Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0ekbDNE2eOq8QiaXM34wer'},
#        'href': 'https://api.spotify.com/v1/artists/0ekbDNE2eOq8QiaXM34wer',
#        'id': '0ekbDNE2eOq8QiaXM34wer',
#        'name': 'Howie Day',
#        'type': 'artist',
#        'uri': 'spotify:artist:0ekbDNE2eOq8QiaXM34wer'}],
#      'available_markets': ['AR',
#       'AU',
#       'BO',
#       'BR',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'DO',
#       'EC',
#       'GT',
#       'HK',
#       'HN',
#       'ID',
#       'IN',
#       'JP',
#       'MX',
#       'MY',
#       'NI',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PY',
#       'SG',
#       'SV',
#       'TH',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0bQBS1GmZ2sqbHcqiQnldn'},
#      'href': 'https://api.spotify.com/v1/albums/0bQBS1GmZ2sqbHcqiQnldn',
#      'id': '0bQBS1GmZ2sqbHcqiQnldn',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27305f94511cc38a2f4652d9f9c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0205f94511cc38a2f4652d9f9c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485105f94511cc38a2f4652d9f9c',
#        'width': 64}],
#      'name': 'Stop All The World Now',
#      'release_date': '2003-10-07',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:0bQBS1GmZ2sqbHcqiQnldn'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0ekbDNE2eOq8QiaXM34wer'},
#       'href': 'https://api.spotify.com/v1/artists/0ekbDNE2eOq8QiaXM34wer',
#       'id': '0ekbDNE2eOq8QiaXM34wer',
#       'name': 'Howie Day',
#       'type': 'artist',
#       'uri': 'spotify:artist:0ekbDNE2eOq8QiaXM34wer'}],
#     'available_markets': ['AR',
#      'AU',
#      'BO',
#      'BR',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'DO',
#      'EC',
#      'GT',
#      'HK',
#      'HN',
#      'ID',
#      'IN',
#      'JP',
#      'MX',
#      'MY',
#      'NI',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PY',
#      'SG',
#      'SV',
#      'TH',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 249120,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM10310894'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6dwkFmLUz6hx2CZG2EqLol'},
#     'href': 'https://api.spotify.com/v1/tracks/6dwkFmLUz6hx2CZG2EqLol',
#     'id': '6dwkFmLUz6hx2CZG2EqLol',
#     'is_local': False,
#     'name': 'Collide',
#     'popularity': 65,
#     'preview_url': 'https://p.scdn.co/mp3-preview/16be24ca116025b9977c87294c7ee78329e7dbc9?cid=d67635d3c8a04dc084f1237db0d3c1d3',
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:6dwkFmLUz6hx2CZG2EqLol'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-04-22T15:52:26Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#        'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#        'id': '6eUKZXaKkcviH0Ku9w2n3V',
#        'name': 'Ed Sheeran',
#        'type': 'artist',
#        'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#      'available_markets': ['AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1xn54DMo2qIqBuMqHtUsFd'},
#      'href': 'https://api.spotify.com/v1/albums/1xn54DMo2qIqBuMqHtUsFd',
#      'id': '1xn54DMo2qIqBuMqHtUsFd',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27313b3e37318a0c247b550bccd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0213b3e37318a0c247b550bccd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485113b3e37318a0c247b550bccd',
#        'width': 64}],
#      'name': 'x (Deluxe Edition)',
#      'release_date': '2014-06-21',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:1xn54DMo2qIqBuMqHtUsFd'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#     'available_markets': ['AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 281560,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHS1400099'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/34gCuhDGsG4bRPIf9bb02f'},
#     'href': 'https://api.spotify.com/v1/tracks/34gCuhDGsG4bRPIf9bb02f',
#     'id': '34gCuhDGsG4bRPIf9bb02f',
#     'is_local': False,
#     'name': 'Thinking out Loud',
#     'popularity': 83,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7fba47d0806142cb34ad2080a5f139eba915fe05?cid=d67635d3c8a04dc084f1237db0d3c1d3',
#     'track': True,
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:34gCuhDGsG4bRPIf9bb02f'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 70}

# %% [markdown]
# Define the analysis function.

# %%
def analyze_playlist(creator, playlist_id):
    
    # Create empty dataframe
    playlist_features_list = ["artist", "album", "track_name", "track_id", 
                             "danceability", "energy", "key", "loudness", "mode", "speechiness",
                             "instrumentalness", "liveness", "valence", "tempo", "duration_ms", "time_signature"]
    playlist_df = pd.DataFrame(columns = playlist_features_list)
    
    # Create empty dict
    playlist_features = {}
    
    # Loop through every track in the playlist, extract features and append the features to the playlist df
    playlist = sp.user_playlist_tracks(creator, playlist_id)["items"]
    for track in playlist:
        # Get metadata
        playlist_features["artist"] = track["track"]["album"]["artists"][0]["name"]
        playlist_features["album"] = track["track"]["album"]["name"]
        playlist_features["track_name"] = track["track"]["name"]
        playlist_features["track_id"] = track["track"]["id"]
        # Get audio features
        audio_features = sp.audio_features(playlist_features["track_id"])[0]
        for feature in playlist_features_list[4:]:
            playlist_features[feature] = audio_features[feature]
        
        # Concat the dfs
        track_df = pd.DataFrame(playlist_features, index = [0])
        playlist_df = pd.concat([playlist_df, track_df], ignore_index = True)
        
    return playlist_df

# %%
playlist_df = analyze_playlist(playlist_creator, playlist_id)

# %%
playlist_df.head()
# Out:
#          artist                               album  \
# 0  James Arthur              Falling Like The Stars
# 1          Lauv                     Spotify Singles
# 2  Taylor Swift  Lover (Remix) [feat. Shawn Mendes]
# 3    Ed Sheeran       Best Part of Me (feat. YEBBA)
# 4   Niall Horan             Put A Little Love On Me
#
#                                           track_name                track_id  \
# 0                             Falling Like The Stars  15xWRPHQMeqgdkGzInx3PY
# 1  I Like Me Better - Recorded at Spotify Studios...  2uQNcZYa0SEbfW4cj0d9OS
# 2                 Lover (Remix) [feat. Shawn Mendes]  3i9UVldZOE0aD0JnyfAZZ0
# 3                      Best Part of Me (feat. YEBBA)  5ug4vqGZ3eisGhY1IsziNX
# 4                            Put A Little Love On Me  1hCTxutVVYvggAQcUUUZAT
#
#    danceability  energy key  loudness mode  speechiness  instrumentalness  \
# 0         0.296   0.351   6    -9.538    1       0.0351          0.000002
# 1         0.454   0.151   9   -13.444    1       0.0600          0.000000
# 2         0.448   0.603   7    -7.176    1       0.0640          0.000000
# 3         0.565   0.242   2    -8.367    1       0.0318          0.000009
# 4         0.584   0.465  10    -4.880    1       0.0262          0.000000
#
#    liveness  valence    tempo duration_ms time_signature
# 0    0.1100    0.190  177.596      212720              3
# 1    0.0792    0.362   90.187      202685              4
# 2    0.0862    0.422  205.272      221307              3
# 3    0.2850    0.237   81.657      243267              4
# 4    0.1060    0.299   95.969      224586              4

# %%
playlist_df.to_csv("filename.csv", index = False)

# %% [markdown]
# ### 3.2 Analyze Multiple Playlists

# %%
playlist_dict = {
    "warm_fuzzy_feeling" : ("spotify", "37i9dQZF1DX5IDTimEWoTd"), 
    "love_songs_heart" : ("indiemono", "5KbTzqKBqxQRD8OBtJTZrS"),
    "romance_songs" : ("Susan Doles", "7sAUK3XK8NHH1s5vGcTBkF")
}

# %%
def analyze_playlist_dict(playlist_dict):
    
    # Loop through every playlist in the dict and analyze it
    for i, (key, val) in enumerate(playlist_dict.items()):
        playlist_df = analyze_playlist(*val)
        # Add a playlist column so that we can see which playlist a track belongs too
        playlist_df["playlist"] = key
        # Create or concat df
        if i == 0:
            playlist_dict_df = playlist_df
        else:
            playlist_dict_df = pd.concat([playlist_dict_df, playlist_df], ignore_index = True)
            
    return playlist_dict_df

# %%
multiple_playlist_df = analyze_playlist_dict(playlist_dict)

# %%
multiple_playlist_df.head()
# Out:
#          artist                               album  \
# 0  James Arthur              Falling Like The Stars
# 1          Lauv                     Spotify Singles
# 2  Taylor Swift  Lover (Remix) [feat. Shawn Mendes]
# 3    Ed Sheeran       Best Part of Me (feat. YEBBA)
# 4   Niall Horan             Put A Little Love On Me
#
#                                           track_name                track_id  \
# 0                             Falling Like The Stars  15xWRPHQMeqgdkGzInx3PY
# 1  I Like Me Better - Recorded at Spotify Studios...  2uQNcZYa0SEbfW4cj0d9OS
# 2                 Lover (Remix) [feat. Shawn Mendes]  3i9UVldZOE0aD0JnyfAZZ0
# 3                      Best Part of Me (feat. YEBBA)  5ug4vqGZ3eisGhY1IsziNX
# 4                            Put A Little Love On Me  1hCTxutVVYvggAQcUUUZAT
#
#    danceability  energy key  loudness mode  speechiness instrumentalness  \
# 0         0.296   0.351   6    -9.538    1       0.0351          1.5e-06
# 1         0.454   0.151   9   -13.444    1       0.0600                0
# 2         0.448   0.603   7    -7.176    1       0.0640                0
# 3         0.565   0.242   2    -8.367    1       0.0318          9.3e-06
# 4         0.584   0.465  10    -4.880    1       0.0262                0
#
#    liveness  valence    tempo duration_ms time_signature            playlist
# 0    0.1100    0.190  177.596      212720              3  warm_fuzzy_feeling
# 1    0.0792    0.362   90.187      202685              4  warm_fuzzy_feeling
# 2    0.0862    0.422  205.272      221307              3  warm_fuzzy_feeling
# 3    0.2850    0.237   81.657      243267              4  warm_fuzzy_feeling
# 4    0.1060    0.299   95.969      224586              4  warm_fuzzy_feeling

# %%
multiple_playlist_df["playlist"].value_counts()
# Out:
# love_songs_heart      100
# romance_songs          77
# warm_fuzzy_feeling     70
# Name: playlist, dtype: int64

# %%
playlist_df.to_csv("filename.csv", index = False)
